# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
games = pd.read_csv('Resources/nfl_data_with_final_win_percentages_plus_opp.csv')
games.head()
# Out:
# C:\Users\stewa\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (83) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Game ID schedule_date  schedule_season schedule_week  schedule_week_clean  \
# 0        1      9/2/1966             1966             1                    1
# 1        1      9/2/1966             1966             1                    1
# 2        2      9/3/1966             1966             1                    1
# 3        2      9/3/1966             1966             1                    1
# 4        3      9/4/1966             1966             1                    1
#
#    schedule_playoff             team team_id  cumulative_win_percent  \
# 0             False   Miami Dolphins     MIA                     0.5
# 1             False  Oakland Raiders     OAK                     0.5
# ...

# %%
train_seasons = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
test_seasons = [2017, 2018]

# %%
games_train = games[(games['schedule_season'] >= 2009) & (games['schedule_season'] <= 2016)]
games_train
# Out:
#        Game ID schedule_date  schedule_season schedule_week  \
# 19482     9742     9/10/2009             2009             1
# 19483     9742     9/10/2009             2009             1
# 19484     9743     9/13/2009             2009             1
# 19485     9743     9/13/2009             2009             1
# 19486     9744     9/13/2009             2009             1
# 19487     9744     9/13/2009             2009             1
# 19488     9745     9/13/2009             2009             1
# 19489     9745     9/13/2009             2009             1
# 19490     9746     9/13/2009             2009             1
# 19491     9746     9/13/2009             2009             1
# 19492     9747     9/13/2009             2009             1
# 19493     9747     9/13/2009             2009             1
# 19494     9748     9/13/2009             2009             1
# 19495     9748     9/13/2009             2009             1
# 19496     9749     9/13/2009             2009             1
# ...

# %%
games_test = games[games['schedule_season'] >= 2017]
games_test
# Out:
#        Game ID schedule_date  schedule_season schedule_week  \
# 23754    11878      9/7/2017             2017             1
# 23755    11878      9/7/2017             2017             1
# 23756    11879     9/10/2017             2017             1
# 23757    11879     9/10/2017             2017             1
# 23758    11880     9/10/2017             2017             1
# 23759    11880     9/10/2017             2017             1
# 23760    11881     9/10/2017             2017             1
# 23761    11881     9/10/2017             2017             1
# 23762    11882     9/10/2017             2017             1
# 23763    11882     9/10/2017             2017             1
# 23764    11883     9/10/2017             2017             1
# 23765    11883     9/10/2017             2017             1
# 23766    11884     9/10/2017             2017             1
# 23767    11884     9/10/2017             2017             1
# 23768    11885     9/10/2017             2017             1
# ...

# %%
games_train_filtered = games_train[[
    'cumulative_win_percent',
    'opp_win_percent',
    'Miami Dolphins',
    'Oakland Raiders',
#     'Houston Oilers',
    'Denver Broncos',
    'San Diego Chargers',
    'Buffalo Bills',
    'Green Bay Packers',
#     'Baltimore Colts',
    'Atlanta Falcons',
#     'Los Angeles Rams',
    'Detroit Lions',
    'Chicago Bears',
    'Pittsburgh Steelers',
    'New York Giants',
    'San Francisco 49ers',
    'Minnesota Vikings',
#     'St. Louis Cardinals',
    'Philadelphia Eagles',
    'Washington Redskins',
    'Cleveland Browns',
    'New York Jets',
    'New England Patriots',
    'Kansas City Chiefs',
    'Dallas Cowboys',
#     'Boston Patriots',
    'New Orleans Saints',
    'Cincinnati Bengals',
    'Tampa Bay Buccaneers',
    'Seattle Seahawks',
#     'Los Angeles Raiders',
    'Indianapolis Colts',
#     'Phoenix Cardinals',
    'Arizona Cardinals',
    'Carolina Panthers',
    'St. Louis Rams',
    'Jacksonville Jaguars',
    'Baltimore Ravens',
#     'Tennessee Oilers',
    'Tennessee Titans',
    'Houston Texans',
#     'Los Angeles Chargers',
    'Home',
    'Away',
    'Favorite_to_Win',
    'Favorite_to_Lose',
    'spread_favorite_clean',
    'stadium_indoors',
    'stadium_outdoors',
    'stadium_retractable',
    'stadium_neutral_true',
    'stadium_neutral_false',
    'temp_below_32',
    'temp_32_to_80',
    'temp_above_80',
    'wind_below_15',
    'wind_GTE_15',
    'win_lose_draw'    
]]
games_train_filtered
# Out:
#        cumulative_win_percent  opp_win_percent  Miami Dolphins  \
# 19482                0.500000         0.500000               0
# 19483                0.500000         0.500000               0
# 19484                0.500000         0.500000               0
# 19485                0.500000         0.500000               0
# 19486                0.500000         0.500000               0
# 19487                0.500000         0.500000               1
# 19488                0.500000         0.500000               0
# 19489                0.500000         0.500000               0
# 19490                0.500000         0.500000               0
# 19491                0.500000         0.500000               0
# 19492                0.500000         0.500000               0
# 19493                0.500000         0.500000               0
# 19494                0.500000         0.500000               0
# 19495                0.500000         0.500000               0
# ...

# %%
games_test_filtered = games_test[[
    'cumulative_win_percent',
    'opp_win_percent',
    'Miami Dolphins',
    'Oakland Raiders',
#     'Houston Oilers',
    'Denver Broncos',
    'San Diego Chargers',
    'Buffalo Bills',
    'Green Bay Packers',
#     'Baltimore Colts',
    'Atlanta Falcons',
#     'Los Angeles Rams',
    'Detroit Lions',
    'Chicago Bears',
    'Pittsburgh Steelers',
    'New York Giants',
    'San Francisco 49ers',
    'Minnesota Vikings',
#     'St. Louis Cardinals',
    'Philadelphia Eagles',
    'Washington Redskins',
    'Cleveland Browns',
    'New York Jets',
    'New England Patriots',
    'Kansas City Chiefs',
    'Dallas Cowboys',
#     'Boston Patriots',
    'New Orleans Saints',
    'Cincinnati Bengals',
    'Tampa Bay Buccaneers',
    'Seattle Seahawks',
#     'Los Angeles Raiders',
    'Indianapolis Colts',
#     'Phoenix Cardinals',
    'Arizona Cardinals',
    'Carolina Panthers',
    'St. Louis Rams',
    'Jacksonville Jaguars',
    'Baltimore Ravens',
#     'Tennessee Oilers',
    'Tennessee Titans',
    'Houston Texans',
#     'Los Angeles Chargers',
    'Home',
    'Away',
    'Favorite_to_Win',
    'Favorite_to_Lose',
    'spread_favorite_clean',
    'stadium_indoors',
    'stadium_outdoors',
    'stadium_retractable',
    'stadium_neutral_true',
    'stadium_neutral_false',
    'temp_below_32',
    'temp_32_to_80',
    'temp_above_80',
    'wind_below_15',
    'wind_GTE_15',
    'win_lose_draw'    
]]
games_test_filtered
# Out:
#        cumulative_win_percent  opp_win_percent  Miami Dolphins  \
# 23754                0.500000         0.500000               0
# 23755                0.500000         0.500000               0
# 23756                0.500000         0.500000               0
# 23757                0.500000         0.500000               0
# 23758                0.500000         0.500000               0
# 23759                0.500000         0.500000               0
# 23760                0.500000         0.500000               0
# 23761                0.500000         0.500000               0
# 23762                0.500000         0.500000               0
# 23763                0.500000         0.500000               0
# 23764                0.500000         0.500000               0
# 23765                0.500000         0.500000               0
# 23766                0.500000         0.500000               0
# 23767                0.500000         0.500000               0
# ...

# %%
#games.drop("stadium_neutral", axis=1, inplace=True)
games_train_filtered.dropna(inplace=True)
games_train_filtered.head(20)
# Out:
# C:\Users\stewa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        cumulative_win_percent  opp_win_percent  Miami Dolphins  \
# 19482                     0.5              0.5               0
# 19483                     0.5              0.5               0
# 19484                     0.5              0.5               0
# 19485                     0.5              0.5               0
# 19486                     0.5              0.5               0
# 19487                     0.5              0.5               1
# 19488                     0.5              0.5               0
# 19489                     0.5              0.5               0
# 19490                     0.5              0.5               0
# ...

# %%
games_test_filtered.dropna(inplace=True)
games_test_filtered.head(20)
# Out:
# C:\Users\stewa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        cumulative_win_percent  opp_win_percent  Miami Dolphins  \
# 23754                     0.5              0.5               0
# 23755                     0.5              0.5               0
# 23756                     0.5              0.5               0
# 23757                     0.5              0.5               0
# 23758                     0.5              0.5               0
# 23759                     0.5              0.5               0
# 23760                     0.5              0.5               0
# 23761                     0.5              0.5               0
# 23762                     0.5              0.5               0
# ...

# %%
names = games_train_filtered.columns[:-1]
correlations = games_train_filtered.corr()
zoom_in_on_columns = ['Away', 'Home', 'Favorite_to_Win']#, 'Favorite_to_Lose']
simpler_correlations = correlations.loc[zoom_in_on_columns, zoom_in_on_columns]
correlations = simpler_correlations
fig = plt.figure(figsize = [25,20])
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(correlations.columns),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(correlations.columns, rotation = 90)
ax.set_yticklabels(correlations.columns)
plt.show()

# %%
correlations.loc[['Away', 'Home', 'Favorite_to_Win', 'Favorite_to_Lose'],['Away', 'Home', 'Favorite_to_Win', 'Favorite_to_Lose']]
# Out:
# C:\Users\stewa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                       Away      Home  Favorite_to_Win  Favorite_to_Lose
# Away              1.000000 -1.000000        -0.342037               NaN
# Home             -1.000000  1.000000         0.342037               NaN
# Favorite_to_Win  -0.342037  0.342037         1.000000               NaN
# Favorite_to_Lose       NaN       NaN              NaN               NaN

# %%
X_train = games_train_filtered.drop("win_lose_draw", axis=1)
y_train = games_train_filtered["win_lose_draw"].values.reshape(-1, 1)
print(X_train.shape, y_train.shape)
# Out:
# (4140, 49) (4140, 1)

# %%
X_test = games_test_filtered.drop("win_lose_draw", axis=1)
y_test = games_test_filtered["win_lose_draw"].values.reshape(-1, 1)
print(X_test.shape, y_test.shape)
# Out:
# (1004, 49) (1004, 1)

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Create a logistic regression model

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\stewa\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\stewa\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\stewa\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
classifier.score(X_train, y_train)
print(f'Clf score on train data is {classifier.score(X_train, y_train)}')
print(f'Clf score on test data is {classifier.score(X_test, y_test)}')
# Out:
# Clf score on train data is 0.6584541062801932
# Clf score on test data is 0.6663346613545816

# %%
predictions = classifier.predict(X_test)

# %%
accuracy = pd.DataFrame({"Prediction": list(predictions), "Actual": y_test.ravel()}).reset_index(drop=True)
accuracy['correct'] = accuracy.Prediction == accuracy.Actual
accuracy.head(15)
# Out:
#     Prediction  Actual  correct
# 0            1       0    False
# 1            0       1    False
# 2            0       0     True
# 3            1       1     True
# 4            0       0     True
# 5            1       1     True
# 6            1       0    False
# 7            0       1    False
# 8            1       1     True
# 9            0       0     True
# 10           0       0     True
# 11           1       1     True
# 12           0       1    False
# 13           1       0    False
# 14           0       0     True

# %%
y_actu = pd.Series(y_test.ravel(), name='Actual')
y_pred = pd.Series(predictions, name='Predicted')
df_confusion = pd.crosstab(y_actu, y_pred)

# %%
df_confusion.columns = ['Win', 'Lose']

# %%
df_confusion.rename(index={
    df_confusion.index[0]: 'Win',
    df_confusion.index[1]: 'Lose',
    df_confusion.index[2]: 'Draw'
}, inplace=True)
df_confusion
# Out:
#         Win  Lose
# Actual
# Win     331   169
# Lose    162   338
# Draw      2     2

# %%
# from sklearn.metrics import confusion_matrix

# tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
# print(tn, fp, fn, tp)

# %%
# games_with_win_perc = pd.read_csv('nfl_data_with_final_win_percentages.csv')
# games_with_win_perc.head()

# %%
# games_with_win_perc.dropna(inplace=True)
# games_with_win_perc.head()

# %%
# X2 = games.drop("win_lose_draw", axis=1)
# y2 = games["win_lose_draw"].values.reshape(-1, 1)
# print(X2.shape, y2.shape)

# %%
# X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, random_state=1, stratify=y)

# %%
# classifier2 = LogisticRegression()
# classifier2

# %%
# classifier2.fit(X2_train, y2_train)

# %%
# classifier2.score(X2_train, y2_train)
# print(f'Clf score on train data is {classifier2.score(X2_train, y2_train)}')
# print(f'Clf score on test data is {classifier2.score(X2_test, y2_test)}')

# %%
y_actu
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
# 5       1
# 6       0
# 7       1
# 8       1
# 9       0
# 10      0
# 11      1
# 12      1
# 13      0
# 14      0
# 15      1
# 16      1
# 17      0
# 18      1
# 19      0
# 20      0
# 21      1
# 22      0
# 23      1
# 24      0
# 25      1
# 26      0
# 27      1
# 28      1
# 29      0
#        ..
# 974     0
# 975     1
# 976     1
# 977     0
# 978     1
# 979     0
# 980     0
# 981     1
# 982     0
# 983     1
# 984     0
# 985     1
# 986     1
# 987     0
# 988     1
# 989     0
# 990     1
# 991     0
# 992     0
# 993     1
# 994     1
# 995     0
# 996     1
# 997     0
# 998     0
# 999     1
# 1000    1
# 1001    0
# 1002    1
# 1003    0
# Name: Actual, Length: 1004, dtype: int64

# %%
y_pred
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
# 5       1
# 6       1
# 7       0
# 8       1
# 9       0
# 10      0
# 11      1
# 12      0
# 13      1
# 14      0
# 15      1
# 16      0
# 17      1
# 18      0
# 19      1
# 20      0
# 21      1
# 22      1
# 23      1
# 24      0
# 25      1
# 26      0
# 27      1
# 28      0
# 29      1
#        ..
# 974     1
# 975     0
# 976     1
# 977     0
# 978     1
# 979     0
# 980     0
# 981     1
# 982     0
# 983     1
# 984     1
# 985     0
# 986     0
# 987     0
# 988     1
# 989     0
# 990     1
# 991     0
# 992     0
# 993     1
# 994     1
# 995     0
# 996     1
# 997     0
# 998     0
# 999     1
# 1000    0
# 1001    1
# 1002    0
# 1003    1
# Name: Predicted, Length: 1004, dtype: int64
