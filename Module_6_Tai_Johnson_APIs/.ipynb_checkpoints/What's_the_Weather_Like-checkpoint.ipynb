# %%
#Import dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
import json
from config import api_key
from pprint import pprint
from citipy import citipy

#Base URL for 
url = "http://api.openweathermap.org/data/2.5/box/city?"

#Grab 649 random cities around the globe
#-----------------------------------------

bbox_nsa = '-175,-60,-30,85,6'    #North and South America bounding box [lon-left,lat-bottom,lon-right,lat-top,zoom]
bbox_aea = '-15,-35,175,85,5'    #Africa, Europe, Asia bounding box [lon-left,lat-bottom,lon-right,lat-top,zoom]

# Build urls
nsa_query_url = f'{url}bbox={bbox_nsa}&APPID={api_key}'
nsa_search_result = requests.get(nsa_query_url)
nsa_search_result = nsa_search_result.json()

aea_query_url = f'{url}bbox={bbox_aea}&APPID={api_key}'
aea_search_result = requests.get(aea_query_url)
aea_search_result = aea_search_result.json()

print(json.dumps(aea_search_result, indent=4))

#Load neccessary data into a dataframe
# cities_list = []
# for x in range(len(nsa_search_result['list'])):
#     cities_list.append(nsa_search_result['list'][x]['name'])
    
# for x in range(len(aea_search_result['list'])):
#     cities_list.append(aea_search_result['list'][x]['name'])
# Out:
# {
#     "cod": 200,
#     "calctime": 0.951165889,
#     "cnt": 326,
#     "list": [
#         {
#             "id": 3370903,
#             "dt": 1553738661,
#             "name": "Jamestown",
#             "coord": {
#                 "Lat": -15.93872,
#                 "Lon": -5.71675
#             },
#             "main": {
#                 "temp": 24.55,
#                 "temp_min": 24.55,
#                 "temp_max": 24.55,
#                 "pressure": 1015.4,
#                 "sea_level": 1015.4,
#                 "grnd_level": 1015.33,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 7.21,
#                 "deg": 118
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 76
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 2274895,
#             "dt": 1553742120,
#             "name": "Monrovia",
#             "coord": {
#                 "Lat": 6.30054,
#                 "Lon": -10.7969
#             },
#             "main": {
#                 "temp": 25,
#                 "temp_min": 25,
#                 "temp_max": 25,
#                 "pressure": 1012,
#                 "humidity": 94
#             },
#             "wind": {
#                 "speed": 1.51,
#                 "deg": 27.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 211,
#                     "main": "Thunderstorm",
#                     "description": "thunderstorm",
#                     "icon": "11n"
#                 }
#             ]
#         },
#         {
#             "id": 2293538,
#             "dt": 1553738616,
#             "name": "Abidjan",
#             "coord": {
#                 "Lat": 5.30943,
#                 "Lon": -4.01972
#             },
#             "main": {
#                 "temp": 28,
#                 "temp_min": 28,
#                 "temp_max": 28,
#                 "pressure": 1012,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 200
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2460596,
#             "dt": 1553742150,
#             "name": "Bamako",
#             "coord": {
#                 "Lat": 12.65,
#                 "Lon": -8
#             },
#             "main": {
#                 "temp": 30,
#                 "temp_min": 30,
#                 "temp_max": 30,
#                 "pressure": 1014,
#                 "humidity": 42
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 0
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2451478,
#             "dt": 1553742127,
#             "name": "Segou",
#             "coord": {
#                 "Lat": 13.4317,
#                 "Lon": -6.2157
#             },
#             "main": {
#                 "temp": 25.9,
#                 "temp_min": 25.9,
#                 "temp_max": 25.9,
#                 "pressure": 1010.16,
#                 "sea_level": 1010.16,
#                 "grnd_level": 977.57,
#                 "humidity": 76
#             },
#             "wind": {
#                 "speed": 1.21,
#                 "deg": 179.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2357048,
#             "dt": 1553742150,
#             "name": "Ouagadougou",
#             "coord": {
#                 "Lat": 12.36423,
#                 "Lon": -1.53834
#             },
#             "main": {
#                 "temp": 25,
#                 "temp_min": 25,
#                 "temp_max": 25,
#                 "pressure": 1012,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 300
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2462881,
#             "dt": 1553738617,
#             "name": "Laayoune / El Aaiun",
#             "coord": {
#                 "Lat": 27.162239,
#                 "Lon": -13.20315
#             },
#             "main": {
#                 "temp": 17,
#                 "temp_min": 17,
#                 "temp_max": 17,
#                 "pressure": 1017,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 2.1,
#                 "deg": 40
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 2461874,
#             "dt": 1553742102,
#             "name": "Smara",
#             "coord": {
#                 "Lat": 26.738411,
#                 "Lon": -11.67194
#             },
#             "main": {
#                 "temp": 14.05,
#                 "temp_min": 14.05,
#                 "temp_max": 14.05,
#                 "pressure": 1015.4,
#                 "sea_level": 1015.4,
#                 "grnd_level": 991.49,
#                 "humidity": 69
#             },
#             "wind": {
#                 "speed": 3.21,
#                 "deg": 24.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 24
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 2561668,
#             "dt": 1553742150,
#             "name": "Agadir",
#             "coord": {
#                 "Lat": 30.420179,
#                 "Lon": -9.59815
#             },
#             "main": {
#                 "temp": 16,
#                 "temp_min": 16,
#                 "temp_max": 16,
#                 "pressure": 1015,
#                 "humidity": 82
#             },
#             "wind": {
#                 "speed": 2.1,
#                 "deg": 140
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 2542997,
#             "dt": 1553742150,
#             "name": "Marrakesh",
#             "coord": {
#                 "Lat": 31.631479,
#                 "Lon": -8.00828
#             },
#             "main": {
#                 "temp": 13,
#                 "temp_min": 13,
#                 "temp_max": 13,
#                 "pressure": 1015,
#                 "humidity": 93
#             },
#             "wind": {
#                 "speed": 1.31,
#                 "deg": 139
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2553604,
#             "dt": 1553742150,
#             "name": "Casablanca",
#             "coord": {
#                 "Lat": 33.592781,
#                 "Lon": -7.61916
#             },
#             "main": {
#                 "temp": 13.56,
#                 "temp_min": 12,
#                 "temp_max": 16.67,
#                 "pressure": 1016,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 0
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 741,
#                     "main": "Fog",
#                     "description": "fog",
#                     "icon": "50n"
#                 }
#             ]
#         },
#         {
#             "id": 2485926,
#             "dt": 1553742150,
#             "name": "Oran",
#             "coord": {
#                 "Lat": 35.691109,
#                 "Lon": -0.64167
#             },
#             "main": {
#                 "temp": 10,
#                 "temp_min": 10,
#                 "temp_max": 10,
#                 "pressure": 1023,
#                 "humidity": 81
#             },
#             "wind": {
#                 "speed": 2.41,
#                 "deg": 45.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 3117735,
#             "dt": 1553742139,
#             "name": "Madrid",
#             "coord": {
#                 "Lat": 40.4165,
#                 "Lon": -3.70256
#             },
#             "main": {
#                 "temp": 6.91,
#                 "temp_min": 4.44,
#                 "temp_max": 9.44,
#                 "pressure": 1026,
#                 "humidity": 44
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 330
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2509954,
#             "dt": 1553738585,
#             "name": "Valencia",
#             "coord": {
#                 "Lat": 39.469749,
#                 "Lon": -0.37739
#             },
#             "main": {
#                 "temp": 7.36,
#                 "temp_min": 4,
#                 "temp_max": 11.11,
#                 "pressure": 1027,
#                 "humidity": 81
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 290
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2965140,
#             "dt": 1553738638,
#             "name": "Cork",
#             "coord": {
#                 "Lat": 51.897968,
#                 "Lon": -8.47061
#             },
#             "main": {
#                 "temp": 6,
#                 "temp_min": 6,
#                 "temp_max": 6,
#                 "pressure": 1036,
#                 "humidity": 87
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 310
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 2964574,
#             "dt": 1553738591,
#             "name": "Dublin",
#             "coord": {
#                 "Lat": 53.34399,
#                 "Lon": -6.26719
#             },
#             "main": {
#                 "temp": 2.36,
#                 "temp_min": 1,
#                 "temp_max": 3.89,
#                 "pressure": 1036,
#                 "humidity": 93
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 280
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 2643741,
#             "dt": 1553738636,
#             "name": "City of London",
#             "coord": {
#                 "Lat": 51.512791,
#                 "Lon": -0.09184
#             },
#             "main": {
#                 "temp": 6.18,
#                 "temp_min": 3.33,
#                 "temp_max": 8.89,
#                 "pressure": 1036,
#                 "humidity": 75
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 0
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 2611396,
#             "dt": 1553742120,
#             "name": "Torshavn",
#             "coord": {
#                 "Lat": 62.009731,
#                 "Lon": -6.77164
#             },
#             "main": {
#                 "temp": 8,
#                 "temp_min": 8,
#                 "temp_max": 8,
#                 "pressure": 1013,
#                 "humidity": 93
#             },
#             "wind": {
#                 "speed": 5.1,
#                 "deg": 220
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 92
#             },
#             "weather": [
#                 {
#                     "id": 701,
#                     "main": "Mist",
#                     "description": "mist",
#                     "icon": "50n"
#                 }
#             ]
#         },
#         {
#             "id": 2657832,
#             "dt": 1553742124,
#             "name": "Aberdeen",
#             "coord": {
#                 "Lat": 57.143688,
#                 "Lon": -2.09814
#             },
#             "main": {
#                 "temp": 5.29,
#                 "temp_min": 3.89,
#                 "temp_max": 10,
#                 "pressure": 1030,
#                 "humidity": 86
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 0
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 3369157,
#             "dt": 1553742150,
#             "name": "Cape Town",
#             "coord": {
#                 "Lat": -33.925838,
#                 "Lon": 18.42322
#             },
#             "main": {
#                 "temp": 15.24,
#                 "temp_min": 13.33,
#                 "temp_max": 17.78,
#                 "pressure": 1018,
#                 "humidity": 87
#             },
#             "wind": {
#                 "speed": 2.1,
#                 "deg": 350
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 945945,
#             "dt": 1553738617,
#             "name": "Upington",
#             "coord": {
#                 "Lat": -28.44776,
#                 "Lon": 21.256121
#             },
#             "main": {
#                 "temp": 22,
#                 "temp_min": 22,
#                 "temp_max": 22,
#                 "pressure": 1020,
#                 "humidity": 26
#             },
#             "wind": {
#                 "speed": 2.6,
#                 "deg": 210
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 3352136,
#             "dt": 1553742150,
#             "name": "Windhoek",
#             "coord": {
#                 "Lat": -22.55941,
#                 "Lon": 17.083229
#             },
#             "main": {
#                 "temp": 19.35,
#                 "temp_min": 19,
#                 "temp_max": 20,
#                 "pressure": 1027,
#                 "humidity": 52
#             },
#             "wind": {
#                 "speed": 0.5,
#                 "deg": 310
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 64
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 3347939,
#             "dt": 1553738619,
#             "name": "Lobito",
#             "coord": {
#                 "Lat": -12.34806,
#                 "Lon": 13.54556
#             },
#             "main": {
#                 "temp": 20.75,
#                 "temp_min": 20.75,
#                 "temp_max": 20.75,
#                 "pressure": 1010.36,
#                 "sea_level": 1010.36,
#                 "grnd_level": 942.85,
#                 "humidity": 85
#             },
#             "wind": {
#                 "speed": 1.61,
#                 "deg": 118
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 24
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 3348313,
#             "dt": 1553738601,
#             "name": "Huambo",
#             "coord": {
#                 "Lat": -12.77611,
#                 "Lon": 15.73917
#             },
#             "main": {
#                 "temp": 13.55,
#                 "temp_min": 13.55,
#                 "temp_max": 13.55,
#                 "pressure": 1012.8,
#                 "sea_level": 1012.8,
#                 "grnd_level": 835.81,
#                 "humidity": 95
#             },
#             "wind": {
#                 "speed": 0.91,
#                 "deg": 154
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 44
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 3353383,
#             "dt": 1553738602,
#             "name": "Rundu",
#             "coord": {
#                 "Lat": -17.933331,
#                 "Lon": 19.76667
#             },
#             "main": {
#                 "temp": 23.95,
#                 "temp_min": 23.95,
#                 "temp_max": 23.95,
#                 "pressure": 1013.4,
#                 "sea_level": 1013.4,
#                 "grnd_level": 892.93,
#                 "humidity": 46
#             },
#             "wind": {
#                 "speed": 5.61,
#                 "deg": 93.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 32
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 2240449,
#             "dt": 1553742150,
#             "name": "Luanda",
#             "coord": {
#                 "Lat": -8.83682,
#                 "Lon": 13.23432
#             },
#             "main": {
#                 "temp": 26.75,
#                 "temp_min": 26.75,
#                 "temp_max": 26.75,
#                 "pressure": 1010.4,
#                 "sea_level": 1010.4,
#                 "grnd_level": 1007.09,
#                 "humidity": 97
#             },
#             "wind": {
#                 "speed": 1.86,
#                 "deg": 178.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 36
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 2239001,
#             "dt": 1553738619,
#             "name": "Nzeto",
#             "coord": {
#                 "Lat": -7.23116,
#                 "Lon": 12.8666
#             },
#             "main": {
#                 "temp": 28.6,
#                 "temp_min": 28.6,
#                 "temp_max": 28.6,
#                 "pressure": 1010.56,
#                 "sea_level": 1010.56,
#                 "grnd_level": 1010.21,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 3.81,
#                 "deg": 171.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 92
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 2314302,
#             "dt": 1553738601,
#             "name": "Kinshasa",
#             "coord": {
#                 "Lat": -4.32459,
#                 "Lon": 15.32146
#             },
#             "main": {
#                 "temp": 24.51,
#                 "temp_min": 24,
#                 "temp_max": 25,
#                 "pressure": 1013,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 1.21,
#                 "deg": 106
#             },
#             "rain": {
#                 "3h": 1.09
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 64
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ]
#         },
#         {
#             "id": 993800,
#             "dt": 1553742150,
#             "name": "Johannesburg",
#             "coord": {
#                 "Lat": -26.202271,
#                 "Lon": 28.043631
#             },
#             "main": {
#                 "temp": 14.86,
#                 "temp_min": 13.33,
#                 "temp_max": 16.67,
#                 "pressure": 1026,
#                 "humidity": 87
#             },
#             "wind": {
#                 "speed": 2.86,
#                 "deg": 328.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 1007311,
#             "dt": 1553742143,
#             "name": "Durban",
#             "coord": {
#                 "Lat": -29.857901,
#                 "Lon": 31.0292
#             },
#             "main": {
#                 "temp": 18.77,
#                 "temp_min": 17.22,
#                 "temp_max": 20,
#                 "pressure": 1015,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 0.5,
#                 "deg": 0
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 1024552,
#             "dt": 1553738601,
#             "name": "Xai-Xai",
#             "coord": {
#                 "Lat": -25.051941,
#                 "Lon": 33.644169
#             },
#             "main": {
#                 "temp": 23.35,
#                 "temp_min": 23.35,
#                 "temp_max": 23.35,
#                 "pressure": 1018.96,
#                 "sea_level": 1018.96,
#                 "grnd_level": 1016.45,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 2.96,
#                 "deg": 42.0003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 12
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 1055429,
#             "dt": 1553738601,
#             "name": "Toliara",
#             "coord": {
#                 "Lat": -23.35,
#                 "Lon": 43.666672
#             },
#             "main": {
#                 "temp": 24.05,
#                 "temp_min": 24.05,
#                 "temp_max": 24.05,
#                 "pressure": 1014.48,
#                 "sea_level": 1014.48,
#                 "grnd_level": 999.73,
#                 "humidity": 96
#             },
#             "wind": {
#                 "speed": 7.16,
#                 "deg": 119
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 933535,
#             "dt": 1553738622,
#             "name": "Letlhakane",
#             "coord": {
#                 "Lat": -21.41667,
#                 "Lon": 25.58333
#             },
#             "main": {
#                 "temp": 19.8,
#                 "temp_min": 19.8,
#                 "temp_max": 19.8,
#                 "pressure": 1017.84,
#                 "sea_level": 1017.84,
#                 "grnd_level": 903.09,
#                 "humidity": 78
#             },
#             "wind": {
#                 "speed": 6.01,
#                 "deg": 76.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 922704,
#             "dt": 1553738601,
#             "name": "Lubumbashi",
#             "coord": {
#                 "Lat": -11.66089,
#                 "Lon": 27.47938
#             },
#             "main": {
#                 "temp": 18,
#                 "temp_min": 18,
#                 "temp_max": 18,
#                 "pressure": 1013.68,
#                 "sea_level": 1013.68,
#                 "grnd_level": 878.21,
#                 "humidity": 90
#             },
#             "wind": {
#                 "speed": 3.46,
#                 "deg": 116.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 8
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 890299,
#             "dt": 1553742150,
#             "name": "Harare",
#             "coord": {
#                 "Lat": -17.82935,
#                 "Lon": 31.05389
#             },
#             "main": {
#                 "temp": 14.15,
#                 "temp_min": 14.15,
#                 "temp_max": 14.15,
#                 "pressure": 1018.24,
#                 "sea_level": 1018.24,
#                 "grnd_level": 862.21,
#                 "humidity": 94
#             },
#             "wind": {
#                 "speed": 3.31,
#                 "deg": 126
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 207570,
#             "dt": 1553742121,
#             "name": "Mwene-Ditu",
#             "coord": {
#                 "Lat": -7,
#                 "Lon": 23.450001
#             },
#             "main": {
#                 "temp": 21.1,
#                 "temp_min": 21.1,
#                 "temp_max": 21.1,
#                 "pressure": 1011.16,
#                 "sea_level": 1011.16,
#                 "grnd_level": 915.97,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 2.66,
#                 "deg": 56.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 209228,
#             "dt": 1553738601,
#             "name": "Mbuji-Mayi",
#             "coord": {
#                 "Lat": -6.15,
#                 "Lon": 23.6
#             },
#             "main": {
#                 "temp": 20.1,
#                 "temp_min": 20.1,
#                 "temp_max": 20.1,
#                 "pressure": 1012.4,
#                 "sea_level": 1012.4,
#                 "grnd_level": 942.45,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 3.66,
#                 "deg": 10.5003
#             },
#             "rain": {
#                 "3h": 3.45
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 32
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 }
#             ]
#         },
#         {
#             "id": 154380,
#             "dt": 1553738600,
#             "name": "Mbeya",
#             "coord": {
#                 "Lat": -8.9,
#                 "Lon": 33.450001
#             },
#             "main": {
#                 "temp": 16.05,
#                 "temp_min": 16.05,
#                 "temp_max": 16.05,
#                 "pressure": 1014.12,
#                 "sea_level": 1014.12,
#                 "grnd_level": 834.61,
#                 "humidity": 95
#             },
#             "wind": {
#                 "speed": 1.01,
#                 "deg": 134
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 80
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 202061,
#             "dt": 1553742120,
#             "name": "Kigali",
#             "coord": {
#                 "Lat": -1.94995,
#                 "Lon": 30.058849
#             },
#             "main": {
#                 "temp": 17.88,
#                 "temp_min": 17.78,
#                 "temp_max": 18,
#                 "pressure": 1021,
#                 "humidity": 93
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 290
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 1033356,
#             "dt": 1553738601,
#             "name": "Nampula",
#             "coord": {
#                 "Lat": -15.11646,
#                 "Lon": 39.266602
#             },
#             "main": {
#                 "temp": 21.1,
#                 "temp_min": 21.1,
#                 "temp_max": 21.1,
#                 "pressure": 1014.52,
#                 "sea_level": 1014.52,
#                 "grnd_level": 961.97,
#                 "humidity": 91
#             },
#             "wind": {
#                 "speed": 2.26,
#                 "deg": 209.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 1035025,
#             "dt": 1553738601,
#             "name": "Cidade de Nacala",
#             "coord": {
#                 "Lat": -14.54278,
#                 "Lon": 40.672779
#             },
#             "main": {
#                 "temp": 25.9,
#                 "temp_min": 25.9,
#                 "temp_max": 25.9,
#                 "pressure": 1013.52,
#                 "sea_level": 1013.52,
#                 "grnd_level": 1011.57,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 4.66,
#                 "deg": 215.5
#             },
#             "rain": {
#                 "3h": 0.28
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 56
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ]
#         },
#         {
#             "id": 160263,
#             "dt": 1553742150,
#             "name": "Dar es Salaam",
#             "coord": {
#                 "Lat": -6.82349,
#                 "Lon": 39.269508
#             },
#             "main": {
#                 "temp": 24.45,
#                 "temp_min": 24.45,
#                 "temp_max": 24.45,
#                 "pressure": 1013.64,
#                 "sea_level": 1013.64,
#                 "grnd_level": 1007.17,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 1.71,
#                 "deg": 253
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 44
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 184745,
#             "dt": 1553742150,
#             "name": "Nairobi",
#             "coord": {
#                 "Lat": -1.28333,
#                 "Lon": 36.816669
#             },
#             "main": {
#                 "temp": 16.09,
#                 "temp_min": 14.44,
#                 "temp_max": 17,
#                 "pressure": 1024,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 20
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 1070940,
#             "dt": 1553738650,
#             "name": "Antananarivo",
#             "coord": {
#                 "Lat": -18.913679,
#                 "Lon": 47.536129
#             },
#             "main": {
#                 "temp": 19,
#                 "temp_min": 19,
#                 "temp_max": 19,
#                 "pressure": 1019,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 2.1,
#                 "deg": 170
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 1061412,
#             "dt": 1553738650,
#             "name": "Mananara Avaratra",
#             "coord": {
#                 "Lat": -16.16667,
#                 "Lon": 49.76667
#             },
#             "main": {
#                 "temp": 24.1,
#                 "temp_min": 24.1,
#                 "temp_max": 24.1,
#                 "pressure": 1012.4,
#                 "sea_level": 1012.4,
#                 "grnd_level": 993.57,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 2.86,
#                 "deg": 187
#             },
#             "rain": {
#                 "3h": 5.87
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 92
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 }
#             ]
#         },
#         {
#             "id": 241131,
#             "dt": 1553738601,
#             "name": "Victoria",
#             "coord": {
#                 "Lat": -4.61667,
#                 "Lon": 55.450001
#             },
#             "main": {
#                 "temp": 28,
#                 "temp_min": 28,
#                 "temp_max": 28,
#                 "pressure": 1011,
#                 "humidity": 78
#             },
#             "wind": {
#                 "speed": 2.1,
#                 "deg": 250
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 934154,
#             "dt": 1553742150,
#             "name": "Port Louis",
#             "coord": {
#                 "Lat": -20.16194,
#                 "Lon": 57.49889
#             },
#             "main": {
#                 "temp": 26.35,
#                 "temp_min": 25.56,
#                 "temp_max": 27,
#                 "pressure": 1011,
#                 "humidity": 78
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 210
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 7304591,
#             "dt": 1553742099,
#             "name": "West Island",
#             "coord": {
#                 "Lat": -12.15681,
#                 "Lon": 96.82251
#             },
#             "main": {
#                 "temp": 29,
#                 "temp_min": 29,
#                 "temp_max": 29,
#                 "pressure": 1014,
#                 "humidity": 70
#             },
#             "wind": {
#                 "speed": 5.7,
#                 "deg": 90
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 1642911,
#             "dt": 1553738638,
#             "name": "Jakarta",
#             "coord": {
#                 "Lat": -6.21462,
#                 "Lon": 106.845131
#             },
#             "main": {
#                 "temp": 29.89,
#                 "temp_min": 27.78,
#                 "temp_max": 32.22,
#                 "pressure": 1013,
#                 "humidity": 74
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 250
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 721,
#                     "main": "Haze",
#                     "description": "haze",
#                     "icon": "50d"
#                 }
#             ]
#         },
#         {
#             "id": 1649150,
#             "dt": 1553738591,
#             "name": "Bengkulu",
#             "coord": {
#                 "Lat": -3.80044,
#                 "Lon": 102.265541
#             },
#             "main": {
#                 "temp": 28.4,
#                 "temp_min": 28.4,
#                 "temp_max": 28.4,
#                 "pressure": 1013.12,
#                 "sea_level": 1013.12,
#                 "grnd_level": 1005.57,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 1.31,
#                 "deg": 178
#             },
#             "rain": {
#                 "3h": 0.89
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 8
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ]
#         },
#         {
#             "id": 1630789,
#             "dt": 1553742120,
#             "name": "Pontianak",
#             "coord": {
#                 "Lat": -0.03333,
#                 "Lon": 109.333328
#             },
#             "main": {
#                 "temp": 27,
#                 "temp_min": 27,
#                 "temp_max": 27,
#                 "pressure": 1014,
#                 "humidity": 88
#             },
#             "wind": {
#                 "speed": 0.76,
#                 "deg": 156.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 2063523,
#             "dt": 1553742152,
#             "name": "Perth",
#             "coord": {
#                 "Lat": -31.933331,
#                 "Lon": 115.833328
#             },
#             "main": {
#                 "temp": 23.31,
#                 "temp_min": 22,
#                 "temp_max": 24.44,
#                 "pressure": 1019,
#                 "humidity": 40
#             },
#             "wind": {
#                 "speed": 5.1,
#                 "deg": 130
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "id": 2068823,
#             "dt": 1553742152,
#             "name": "Boulder",
#             "coord": {
#                 "Lat": -30.75,
#                 "Lon": 121.466667
#             },
#             "main": {
#                 "temp": 23,
#                 "temp_min": 23,
#                 "temp_max": 23,
#                 "pressure": 1016,
#                 "humidity": 53
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 130
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "id": 2077895,
#             "dt": 1553742095,
#             "name": "Alice Springs",
#             "coord": {
#                 "Lat": -23.700001,
#                 "Lon": 133.883331
#             },
#             "main": {
#                 "temp": 27,
#                 "temp_min": 27,
#                 "temp_max": 27,
#                 "pressure": 1015,
#                 "humidity": 21
#             },
#             "wind": {
#                 "speed": 3.6,
#                 "deg": 160
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
# ...
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ]
#         },
#         {
#             "id": 2037013,
#             "dt": 1553742154,
#             "name": "Harbin",
#             "coord": {
#                 "Lat": 45.75,
#                 "Lon": 126.650002
#             },
#             "main": {
#                 "temp": 1,
#                 "temp_min": 1,
#                 "temp_max": 1,
#                 "pressure": 1015,
#                 "humidity": 22
#             },
#             "wind": {
#                 "speed": 5,
#                 "deg": 30
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "id": 2026609,
#             "dt": 1553742146,
#             "name": "Blagoveshchensk",
#             "coord": {
#                 "Lat": 50.26667,
#                 "Lon": 127.533333
#             },
#             "main": {
#                 "temp": -2,
#                 "temp_min": -2,
#                 "temp_max": -2,
#                 "pressure": 1012,
#                 "humidity": 30
#             },
#             "wind": {
#                 "speed": 6,
#                 "deg": 360
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 2014718,
#             "dt": 1553742146,
#             "name": "Tynda",
#             "coord": {
#                 "Lat": 55.166672,
#                 "Lon": 124.716667
#             },
#             "main": {
#                 "temp": -8.45,
#                 "temp_min": -8.45,
#                 "temp_max": -8.45,
#                 "pressure": 1017.4,
#                 "sea_level": 1017.4,
#                 "grnd_level": 937.33,
#                 "humidity": 46
#             },
#             "wind": {
#                 "speed": 2.51,
#                 "deg": 10.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 44
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 2036986,
#             "dt": 1553742155,
#             "name": "Hegang",
#             "coord": {
#                 "Lat": 47.400002,
#                 "Lon": 130.366669
#             },
#             "main": {
#                 "temp": -1.55,
#                 "temp_min": -1.55,
#                 "temp_max": -1.55,
#                 "pressure": 1013.88,
#                 "sea_level": 1013.88,
#                 "grnd_level": 984.45,
#                 "humidity": 43
#             },
#             "wind": {
#                 "speed": 3.46,
#                 "deg": 319
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 36
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 2019309,
#             "dt": 1553742138,
#             "name": "Neryungri",
#             "coord": {
#                 "Lat": 56.670898,
#                 "Lon": 124.649101
#             },
#             "main": {
#                 "temp": -12,
#                 "temp_min": -12,
#                 "temp_max": -12,
#                 "pressure": 1018.4,
#                 "sea_level": 1018.4,
#                 "grnd_level": 898.45,
#                 "humidity": 59
#             },
#             "wind": {
#                 "speed": 4.41,
#                 "deg": 8.00027
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 44
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 2013159,
#             "dt": 1553742141,
#             "name": "Yakutsk",
#             "coord": {
#                 "Lat": 62.03389,
#                 "Lon": 129.733063
#             },
#             "main": {
#                 "temp": -14,
#                 "temp_min": -14,
#                 "temp_max": -14,
#                 "pressure": 1017,
#                 "humidity": 55
#             },
#             "wind": {
#                 "speed": 3,
#                 "deg": 130
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "id": 7828758,
#             "dt": 1553738651,
#             "name": "Saipan",
#             "coord": {
#                 "Lat": 15.21233,
#                 "Lon": 145.754501
#             },
#             "main": {
#                 "temp": 31,
#                 "temp_min": 31,
#                 "temp_max": 31,
#                 "pressure": 1014,
#                 "humidity": 48
#             },
#             "wind": {
#                 "speed": 7.2,
#                 "deg": 60
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 1850144,
#             "dt": 1553742092,
#             "name": "T\u014dky\u014d-to",
#             "coord": {
#                 "Lat": 35.689499,
#                 "Lon": 139.691711
#             },
#             "main": {
#                 "temp": 15.97,
#                 "temp_min": 12.22,
#                 "temp_max": 18.33,
#                 "pressure": 1006,
#                 "humidity": 76
#             },
#             "wind": {
#                 "speed": 6.7,
#                 "deg": 70
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 1850147,
#             "dt": 1553742141,
#             "name": "Tokyo",
#             "coord": {
#                 "Lat": 35.689499,
#                 "Lon": 139.691711
#             },
#             "main": {
#                 "temp": 15.97,
#                 "temp_min": 12.22,
#                 "temp_max": 18.33,
#                 "pressure": 1006,
#                 "humidity": 76
#             },
#             "wind": {
#                 "speed": 6.7,
#                 "deg": 70
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 2128295,
#             "dt": 1553742096,
#             "name": "Sapporo-shi",
#             "coord": {
#                 "Lat": 43.064171,
#                 "Lon": 141.346939
#             },
#             "main": {
#                 "temp": 1.17,
#                 "temp_min": 0,
#                 "temp_max": 2.22,
#                 "pressure": 1005,
#                 "humidity": 59
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 310
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 620,
#                     "main": "Snow",
#                     "description": "light shower snow",
#                     "icon": "13d"
#                 }
#             ]
#         },
#         {
#             "id": 2130629,
#             "dt": 1553742156,
#             "name": "Asahikawa",
#             "coord": {
#                 "Lat": 43.76778,
#                 "Lon": 142.370285
#             },
#             "main": {
#                 "temp": -1.99,
#                 "temp_min": -3,
#                 "temp_max": -1,
#                 "pressure": 1002,
#                 "humidity": 86
#             },
#             "wind": {
#                 "speed": 8.2,
#                 "deg": 320
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 620,
#                     "main": "Snow",
#                     "description": "light shower snow",
#                     "icon": "13d"
#                 }
#             ]
#         },
#         {
#             "id": 2128975,
#             "dt": 1553742119,
#             "name": "Nemuro",
#             "coord": {
#                 "Lat": 43.323608,
#                 "Lon": 145.574997
#             },
#             "main": {
#                 "temp": 1,
#                 "temp_min": 1,
#                 "temp_max": 1,
#                 "pressure": 1000,
#                 "humidity": 64
#             },
#             "wind": {
#                 "speed": 5.7,
#                 "deg": 260
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 620,
#                     "main": "Snow",
#                     "description": "light shower snow",
#                     "icon": "13d"
#                 }
#             ]
#         },
#         {
#             "id": 2081986,
#             "dt": 1553738632,
#             "name": "Palikir - National Government Center",
#             "coord": {
#                 "Lat": 6.92477,
#                 "Lon": 158.161087
#             },
#             "main": {
#                 "temp": 29,
#                 "temp_min": 29,
#                 "temp_max": 29,
#                 "pressure": 1011,
#                 "humidity": 79
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 60
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 2110257,
#             "dt": 1553738650,
#             "name": "Tarawa",
#             "coord": {
#                 "Lat": 1.3278,
#                 "Lon": 172.976959
#             },
#             "main": {
#                 "temp": 24,
#                 "temp_min": 24,
#                 "temp_max": 24,
#                 "pressure": 1009,
#                 "humidity": 94
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 250
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ]
#         },
#         {
#             "id": 2113779,
#             "dt": 1553738650,
#             "name": "Majuro",
#             "coord": {
#                 "Lat": 7.08971,
#                 "Lon": 171.380264
#             },
#             "main": {
#                 "temp": 30,
#                 "temp_min": 30,
#                 "temp_max": 30,
#                 "pressure": 1008,
#                 "humidity": 70
#             },
#             "wind": {
#                 "speed": 5.1,
#                 "deg": 60
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 2122850,
#             "dt": 1553742151,
#             "name": "Nikolayevsk-na-Amure",
#             "coord": {
#                 "Lat": 53.14056,
#                 "Lon": 140.729996
#             },
#             "main": {
#                 "temp": -6.95,
#                 "temp_min": -6.95,
#                 "temp_max": -6.95,
#                 "pressure": 1007.72,
#                 "sea_level": 1007.72,
#                 "grnd_level": 998.45,
#                 "humidity": 92
#             },
#             "wind": {
#                 "speed": 5.61,
#                 "deg": 13.5003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 80
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 2123628,
#             "dt": 1553742096,
#             "name": "Magadan",
#             "coord": {
#                 "Lat": 59.566669,
#                 "Lon": 150.800003
#             },
#             "main": {
#                 "temp": -5.6,
#                 "temp_min": -5.6,
#                 "temp_max": -5.6,
#                 "pressure": 1010.24,
#                 "sea_level": 1010.24,
#                 "grnd_level": 1004.69,
#                 "humidity": 100
#             },
#             "wind": {
#                 "speed": 5.81,
#                 "deg": 56.0003
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 36
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 2122104,
#             "dt": 1553742147,
#             "name": "Petropavlovsk-Kamchatskiy",
#             "coord": {
#                 "Lat": 53.0452,
#                 "Lon": 158.6483
#             },
#             "main": {
#                 "temp": 2,
#                 "temp_min": 2,
#                 "temp_max": 2,
#                 "pressure": 990,
#                 "humidity": 37
#             },
#             "wind": {
#                 "speed": 6,
#                 "deg": 290
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 76
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         }
#     ]
# }
