# %%
#Import dependencies
import requests
import json
import numpy as np
from config import api_key
from pprint import pprint
from citipy import citipy

# rand_lat = np.random.randint(-90, 90, 500)
# rand_long = np.random.randint(-180, 180, 500)
# rand_coords = list(zip(rand_lat, rand_long))
# city = citipy.nearest_city(rand_lat[0], rand_long[0])
# print(rand_coords)
# print(city.city_name)

url = "http://api.openweathermap.org/data/2.5/box/city?"

#City code
bbox_nsa = '-175,-60,-30,85,6'    #North and South America bounding box [lon-left,lat-bottom,lon-right,lat-top,zoom]
bbox_aea = '-15,-35,175,85,6'    #Africa, Europe, Asia bounding box [lon-left,lat-bottom,lon-right,lat-top,zoom]
bbox_ant = '-180,-90,180,-55,6'    #Antartica bounding box [lon-left,lat-bottom,lon-right,lat-top,zoom]

# Build url
nsa_query_url = f'{url}bbox={bbox_nsa}&APPID={api_key}'
nsa_search_result = requests.get(nsa_query_url)
nsa_search_result = nsa_search_result.json()

aea_query_url = f'{url}bbox={bbox_aea}&APPID={api_key}'
aea_search_result = requests.get(aea_query_url)
aea_search_result = aea_search_result.json()

ant_query_url = f'{url}bbox={bbox_ant}&APPID={api_key}'
ant_search_result = requests.get(ant_search_result)
ant_search_result = ant_search_result.json()


print(json.dumps(na_search_result, indent=4))
# Out:
# {
#     "cod": 200,
#     "calctime": 0.863696251,
#     "cnt": 174,
#     "list": [
#         {
#             "id": 5856195,
#             "dt": 1553735088,
#             "name": "Honolulu",
#             "coord": {
#                 "Lat": 21.30694,
#                 "Lon": -157.858337
#             },
#             "main": {
#                 "temp": 26.2,
#                 "temp_min": 24.44,
#                 "temp_max": 27,
#                 "pressure": 1011,
#                 "humidity": 61
#             },
#             "wind": {
#                 "speed": 3.6,
#                 "deg": 50
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5855927,
#             "dt": 1553734914,
#             "name": "Hilo",
#             "coord": {
#                 "Lat": 19.729719,
#                 "Lon": -155.089996
#             },
#             "main": {
#                 "temp": 22.78,
#                 "temp_min": 18.89,
#                 "temp_max": 26,
#                 "pressure": 1012,
#                 "humidity": 57
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 90
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5879400,
#             "dt": 1553735088,
#             "name": "Anchorage",
#             "coord": {
#                 "Lat": 61.21806,
#                 "Lon": -149.900284
#             },
#             "main": {
#                 "temp": 8.35,
#                 "temp_min": 6.67,
#                 "temp_max": 9.44,
#                 "pressure": 1023,
#                 "humidity": 49
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 340
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5861897,
#             "dt": 1553735088,
#             "name": "Fairbanks",
#             "coord": {
#                 "Lat": 64.837784,
#                 "Lon": -147.716385
#             },
#             "main": {
#                 "temp": 4.37,
#                 "temp_min": 3.33,
#                 "temp_max": 5,
#                 "pressure": 1026,
#                 "humidity": 69
#             },
#             "wind": {
#                 "speed": 1.71,
#                 "deg": 250
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 6180550,
#             "dt": 1553734894,
#             "name": "Whitehorse",
#             "coord": {
#                 "Lat": 60.71611,
#                 "Lon": -135.053757
#             },
#             "main": {
#                 "temp": 9.72,
#                 "temp_min": 8.89,
#                 "temp_max": 10,
#                 "pressure": 1020,
#                 "humidity": 29
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 10
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 3996069,
#             "dt": 1553734968,
#             "name": "Mexicali",
#             "coord": {
#                 "Lat": 32.651939,
#                 "Lon": -115.46833
#             },
#             "main": {
#                 "temp": 27.09,
#                 "temp_min": 26,
#                 "temp_max": 28,
#                 "pressure": 1013,
#                 "humidity": 21
#             },
#             "wind": {
#                 "speed": 6.7,
#                 "deg": 270
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 3984237,
#             "dt": 1553734925,
#             "name": "Santa Isabel",
#             "coord": {
#                 "Lat": 28.383329,
#                 "Lon": -113.349998
#             },
#             "main": {
#                 "temp": 24.62,
#                 "temp_min": 24.62,
#                 "temp_max": 24.62,
#                 "pressure": 1013.49,
#                 "sea_level": 1013.49,
#                 "grnd_level": 959.3,
#                 "humidity": 17
#             },
#             "wind": {
#                 "speed": 3.41,
#                 "deg": 262
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 80
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5391959,
#             "dt": 1553735085,
#             "name": "San Francisco",
#             "coord": {
#                 "Lat": 37.774929,
#                 "Lon": -122.419418
#             },
#             "main": {
#                 "temp": 14.52,
#                 "temp_min": 12.78,
#                 "temp_max": 16.11,
#                 "pressure": 1016,
#                 "humidity": 76
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 230
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5392171,
#             "dt": 1553735085,
#             "name": "San Jose",
#             "coord": {
#                 "Lat": 37.33939,
#                 "Lon": -121.894958
#             },
#             "main": {
#                 "temp": 15.21,
#                 "temp_min": 11.67,
#                 "temp_max": 17.78,
#                 "pressure": 1016,
#                 "humidity": 51
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 270
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 521,
#                     "main": "Rain",
#                     "description": "shower rain",
#                     "icon": "09n"
#                 }
#             ]
#         },
#         {
#             "id": 5368361,
#             "dt": 1553735084,
#             "name": "Los Angeles",
#             "coord": {
#                 "Lat": 34.052231,
#                 "Lon": -118.243683
#             },
#             "main": {
#                 "temp": 17.72,
#                 "temp_min": 15,
#                 "temp_max": 21,
#                 "pressure": 1018,
#                 "humidity": 77
#             },
#             "wind": {
#                 "speed": 8.2,
#                 "deg": 250
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5350937,
#             "dt": 1553735083,
#             "name": "Fresno",
#             "coord": {
#                 "Lat": 36.74773,
#                 "Lon": -119.772369
#             },
#             "main": {
#                 "temp": 17.59,
#                 "temp_min": 10,
#                 "temp_max": 23,
#                 "pressure": 1016,
#                 "humidity": 52
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 140
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5570160,
#             "dt": 1553735086,
#             "name": "Redding",
#             "coord": {
#                 "Lat": 40.58654,
#                 "Lon": -122.391678
#             },
#             "main": {
#                 "temp": 12.84,
#                 "temp_min": 7.22,
#                 "temp_max": 17,
#                 "pressure": 1010,
#                 "humidity": 63
#             },
#             "wind": {
#                 "speed": 11.3,
#                 "deg": 160
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 211,
#                     "main": "Thunderstorm",
#                     "description": "thunderstorm",
#                     "icon": "11n"
#                 }
#             ]
#         },
#         {
#             "id": 5740099,
#             "dt": 1553735087,
#             "name": "Medford",
#             "coord": {
#                 "Lat": 42.326519,
#                 "Lon": -122.875587
#             },
#             "main": {
#                 "temp": 11.51,
#                 "temp_min": 8.33,
#                 "temp_max": 13.33,
#                 "pressure": 1012,
#                 "humidity": 50
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 0
#             },
#             "rain": {
#                 "1h": 1.27
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 }
#             ]
#         },
#         {
#             "id": 5725846,
#             "dt": 1553735087,
#             "name": "Eugene",
#             "coord": {
#                 "Lat": 44.052071,
#                 "Lon": -123.086746
#             },
#             "main": {
#                 "temp": 11.82,
#                 "temp_min": 8.89,
#                 "temp_max": 14.44,
#                 "pressure": 1011,
#                 "humidity": 58
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 240
#             },
#             "rain": {
#                 "1h": 0.25
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10n"
#                 }
#             ]
#         },
#         {
#             "id": 5506956,
#             "dt": 1553735086,
#             "name": "Las Vegas",
#             "coord": {
#                 "Lat": 36.174969,
#                 "Lon": -115.137222
#             },
#             "main": {
#                 "temp": 23.63,
#                 "temp_min": 20.56,
#                 "temp_max": 25,
#                 "pressure": 1012,
#                 "humidity": 8
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 210
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 5536630,
#             "dt": 1553735017,
#             "name": "Cedar City",
#             "coord": {
#                 "Lat": 37.677479,
#                 "Lon": -113.06189
#             },
#             "main": {
#                 "temp": 15.46,
#                 "temp_min": 15,
#                 "temp_max": 16,
#                 "pressure": 1016,
#                 "humidity": 13
#             },
#             "wind": {
#                 "speed": 11.3,
#                 "deg": 190
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5703670,
#             "dt": 1553734929,
#             "name": "Elko",
#             "coord": {
#                 "Lat": 40.83242,
#                 "Lon": -115.763123
#             },
#             "main": {
#                 "temp": 14.25,
#                 "temp_min": 12.78,
#                 "temp_max": 16,
#                 "pressure": 1010,
#                 "humidity": 23
#             },
#             "wind": {
#                 "speed": 6.7,
#                 "deg": 290
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 5601933,
#             "dt": 1553735086,
#             "name": "Nampa",
#             "coord": {
#                 "Lat": 43.540722,
#                 "Lon": -116.563461
#             },
#             "main": {
#                 "temp": 11.52,
#                 "temp_min": 10,
#                 "temp_max": 13.33,
#                 "pressure": 1011,
#                 "humidity": 87
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 350
#             },
#             "rain": {
#                 "1h": 1.4
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 },
#                 {
#                     "id": 200,
#                     "main": "Thunderstorm",
#                     "description": "thunderstorm with light rain",
#                     "icon": "11n"
#                 }
#             ]
#         },
#         {
#             "id": 5587698,
#             "dt": 1553735086,
#             "name": "Caldwell",
#             "coord": {
#                 "Lat": 43.662941,
#                 "Lon": -116.687363
#             },
#             "main": {
#                 "temp": 11.53,
#                 "temp_min": 10,
#                 "temp_max": 13.33,
#                 "pressure": 1011,
#                 "humidity": 87
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 350
#             },
#             "rain": {
#                 "1h": 1.4
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 },
#                 {
#                     "id": 200,
#                     "main": "Thunderstorm",
#                     "description": "thunderstorm with light rain",
#                     "icon": "11n"
#                 }
#             ]
#         },
#         {
#             "id": 5586437,
#             "dt": 1553735086,
#             "name": "Boise",
#             "coord": {
#                 "Lat": 43.613499,
#                 "Lon": -116.203453
#             },
#             "main": {
#                 "temp": 11.87,
#                 "temp_min": 10,
#                 "temp_max": 16,
#                 "pressure": 1011,
#                 "humidity": 87
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 350
#             },
#             "rain": {
#                 "1h": 2.29
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 },
#                 {
#                     "id": 200,
#                     "main": "Thunderstorm",
#                     "description": "thunderstorm with light rain",
#                     "icon": "11n"
#                 }
#             ]
#         },
#         {
#             "id": 4017957,
#             "dt": 1553734969,
#             "name": "Autlan de Navarro",
#             "coord": {
#                 "Lat": 19.76667,
#                 "Lon": -104.366669
#             },
#             "main": {
#                 "temp": 27.17,
#                 "temp_min": 27.17,
#                 "temp_max": 27.17,
#                 "pressure": 1011.17,
#                 "sea_level": 1011.17,
#                 "grnd_level": 881.14,
#                 "humidity": 21
#             },
#             "wind": {
#                 "speed": 1.51,
#                 "deg": 227.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 4005539,
#             "dt": 1553734967,
#             "name": "Guadalajara",
#             "coord": {
#                 "Lat": 20.66667,
#                 "Lon": -103.333328
#             },
#             "main": {
#                 "temp": 29,
#                 "temp_min": 29,
#                 "temp_max": 29,
#                 "pressure": 1020,
#                 "humidity": 13
#             },
#             "wind": {
#                 "speed": 1.31,
#                 "deg": 104.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 3533462,
#             "dt": 1553735049,
#             "name": "Acapulco de Juarez",
#             "coord": {
#                 "Lat": 16.863359,
#                 "Lon": -99.890099
#             },
#             "main": {
#                 "temp": 29,
#                 "temp_min": 29,
#                 "temp_max": 29,
#                 "pressure": 1009,
#                 "humidity": 70
#             },
#             "wind": {
#                 "speed": 3.6,
#                 "deg": 240
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 5
#             },
#             "weather": [
#                 {
#                     "id": 711,
#                     "main": "Smoke",
#                     "description": "smoke",
#                     "icon": "50d"
#                 }
#             ]
#         },
#         {
#             "id": 3530597,
#             "dt": 1553734939,
#             "name": "Mexico City",
#             "coord": {
#                 "Lat": 19.428471,
#                 "Lon": -99.127663
#             },
#             "main": {
#                 "temp": 23.91,
#                 "temp_min": 21.67,
#                 "temp_max": 29,
#                 "pressure": 1026,
#                 "humidity": 14
#             },
#             "wind": {
#                 "speed": 7.7,
#                 "deg": 20
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 3521081,
#             "dt": 1553734967,
#             "name": "Puebla de Zaragoza",
#             "coord": {
#                 "Lat": 19.049999,
#                 "Lon": -98.199997
#             },
#             "main": {
#                 "temp": 22,
#                 "temp_min": 22,
#                 "temp_max": 22,
#                 "pressure": 1026,
#                 "humidity": 15
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 170
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ]
#         },
#         {
#             "id": 3514783,
#             "dt": 1553734967,
#             "name": "Veracruz",
#             "coord": {
#                 "Lat": 19.200001,
#                 "Lon": -96.133331
#             },
#             "main": {
#                 "temp": 25,
#                 "temp_min": 25,
#                 "temp_max": 25,
#                 "pressure": 1020,
#                 "humidity": 73
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 50
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 5
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "02d"
#                 }
#             ]
#         },
#         {
#             "id": 3516355,
#             "dt": 1553734968,
#             "name": "Tampico",
#             "coord": {
#                 "Lat": 22.216669,
#                 "Lon": -97.849998
#             },
#             "main": {
#                 "temp": 23,
#                 "temp_min": 23,
#                 "temp_max": 23,
#                 "pressure": 1020,
#                 "humidity": 83
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 90
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 3515001,
#             "dt": 1553734968,
#             "name": "Tuxtla Gutierrez",
#             "coord": {
#                 "Lat": 16.75,
#                 "Lon": -93.116669
#             },
#             "main": {
#                 "temp": 30,
#                 "temp_min": 30,
#                 "temp_max": 30,
#                 "pressure": 1015,
#                 "humidity": 30
#             },
#             "wind": {
#                 "speed": 7.7,
#                 "deg": 360
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "id": 3598132,
#             "dt": 1553735013,
#             "name": "Guatemala City",
#             "coord": {
#                 "Lat": 14.64072,
#                 "Lon": -90.513268
#             },
#             "main": {
#                 "temp": 20,
#                 "temp_min": 20,
#                 "temp_max": 20,
#                 "pressure": 1025,
#                 "humidity": 56
#             },
#             "wind": {
#                 "speed": 9.3,
#                 "deg": 40
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 3515956,
#             "dt": 1553734968,
#             "name": "Tenosique de Pino Suarez",
#             "coord": {
#                 "Lat": 17.48333,
#                 "Lon": -91.433327
#             },
#             "main": {
#                 "temp": 26,
#                 "temp_min": 26,
#                 "temp_max": 26,
#                 "pressure": 1013,
#                 "humidity": 78
#             },
#             "wind": {
#                 "speed": 1.96,
#                 "deg": 326
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 4013723,
#             "dt": 1553734910,
#             "name": "Ciudad Constitucion",
#             "coord": {
#                 "Lat": 25.03694,
#                 "Lon": -111.664436
#             },
#             "main": {
#                 "temp": 26.42,
#                 "temp_min": 26.42,
#                 "temp_max": 26.42,
#                 "pressure": 1014.01,
#                 "sea_level": 1014.01,
#                 "grnd_level": 1000.42,
#                 "humidity": 19
#             },
#             "wind": {
#                 "speed": 4.31,
#                 "deg": 288
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 48
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 3986172,
#             "dt": 1553734968,
#             "name": "San Jose del Cabo",
#             "coord": {
#                 "Lat": 23.05888,
#                 "Lon": -109.697708
#             },
#             "main": {
#                 "temp": 25.51,
#                 "temp_min": 21.11,
#                 "temp_max": 28.89,
#                 "pressure": 1014,
#                 "humidity": 24
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 130
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 4000900,
#             "dt": 1553734968,
#             "name": "La Paz",
#             "coord": {
#                 "Lat": 24.16667,
#                 "Lon": -110.300003
#             },
#             "main": {
#                 "temp": 27.35,
#                 "temp_min": 23.89,
#                 "temp_max": 31,
#                 "pressure": 1014,
#                 "humidity": 11
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 320
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 4012176,
#             "dt": 1553734894,
#             "name": "Culiacan",
#             "coord": {
#                 "Lat": 24.79944,
#                 "Lon": -107.389717
#             },
#             "main": {
#                 "temp": 25.71,
#                 "temp_min": 24.44,
#                 "temp_max": 27.78,
#                 "pressure": 1008,
#                 "humidity": 54
#             },
#             "wind": {
#                 "speed": 0.89,
#                 "deg": 202
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 3997479,
#             "dt": 1553734968,
#             "name": "Los Mochis",
#             "coord": {
#                 "Lat": 25.76667,
#                 "Lon": -108.966667
#             },
#             "main": {
#                 "temp": 25.62,
#                 "temp_min": 25,
#                 "temp_max": 27.22,
#                 "pressure": 1014,
#                 "humidity": 27
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 230
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 4004887,
#             "dt": 1553734969,
#             "name": "Heroica Caborca",
#             "coord": {
#                 "Lat": 30.716669,
#                 "Lon": -112.150002
#             },
#             "main": {
#                 "temp": 26.33,
#                 "temp_min": 25.56,
#                 "temp_max": 27.22,
#                 "pressure": 1012,
#                 "humidity": 16
#             },
#             "wind": {
#                 "speed": 4.47,
#                 "deg": 270
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 76
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 4004898,
#             "dt": 1553735049,
#             "name": "Hermosillo",
#             "coord": {
#                 "Lat": 29.066669,
#                 "Lon": -110.966667
#             },
#             "main": {
#                 "temp": 28.67,
#                 "temp_min": 26.67,
#                 "temp_max": 30,
#                 "pressure": 1016,
#                 "humidity": 18
#             },
#             "wind": {
#                 "speed": 0.45,
#                 "deg": 245
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 68
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5308655,
#             "dt": 1553735082,
#             "name": "Phoenix",
#             "coord": {
#                 "Lat": 33.44838,
#                 "Lon": -112.074043
#             },
#             "main": {
#                 "temp": 25.85,
#                 "temp_min": 23.89,
#                 "temp_max": 28,
#                 "pressure": 1014,
#                 "humidity": 19
#             },
#             "wind": {
#                 "speed": 1.41,
#                 "deg": 326
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 4019260,
#             "dt": 1553734969,
#             "name": "Agua Prieta",
#             "coord": {
#                 "Lat": 31.299999,
#                 "Lon": -109.566673
#             },
#             "main": {
#                 "temp": 23.34,
#                 "temp_min": 21.67,
#                 "temp_max": 25,
#                 "pressure": 1020,
#                 "humidity": 13
#             },
#             "wind": {
#                 "speed": 1.79,
#                 "deg": 280
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 64
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 4011743,
#             "dt": 1553734917,
#             "name": "Durango",
#             "coord": {
#                 "Lat": 24.033331,
#                 "Lon": -104.666672
#             },
#             "main": {
#                 "temp": 25.65,
#                 "temp_min": 23.89,
#                 "temp_max": 27,
#                 "pressure": 1021,
#                 "humidity": 10
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 140
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 3979844,
#             "dt": 1553734967,
#             "name": "Zacatecas",
#             "coord": {
#                 "Lat": 22.775591,
#                 "Lon": -102.572182
#             },
#             "main": {
#                 "temp": 25,
#                 "temp_min": 25,
#                 "temp_max": 25,
#                 "pressure": 1023,
#                 "humidity": 23
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 30
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "id": 4014338,
#             "dt": 1553734917,
#             "name": "Chihuahua",
#             "coord": {
#                 "Lat": 28.633329,
#                 "Lon": -106.083328
#             },
#             "main": {
#                 "temp": 28.75,
#                 "temp_min": 26.67,
#                 "temp_max": 31,
#                 "pressure": 1017,
#                 "humidity": 14
#             },
#             "wind": {
#                 "speed": 5.1,
#                 "deg": 140
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 4013708,
#             "dt": 1553734917,
#             "name": "Ciudad Juarez",
#             "coord": {
#                 "Lat": 31.73333,
#                 "Lon": -106.48333
#             },
#             "main": {
#                 "temp": 26.58,
#                 "temp_min": 24.44,
#                 "temp_max": 29,
#                 "pressure": 1017,
#                 "humidity": 8
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 260
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5488441,
#             "dt": 1553734914,
#             "name": "Roswell",
#             "coord": {
#                 "Lat": 33.394272,
#                 "Lon": -104.523018
#             },
#             "main": {
#                 "temp": 26.53,
#                 "temp_min": 24.44,
#                 "temp_max": 29,
#                 "pressure": 1015,
#                 "humidity": 29
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 180
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5525577,
#             "dt": 1553734929,
#             "name": "Lubbock",
#             "coord": {
#                 "Lat": 33.577862,
#                 "Lon": -101.855171
#             },
#             "main": {
#                 "temp": 22.56,
#                 "temp_min": 22,
#                 "temp_max": 23,
#                 "pressure": 1017,
#                 "humidity": 49
#             },
#             "wind": {
#                 "speed": 8.7,
#                 "deg": 180
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5423573,
#             "dt": 1553734890,
#             "name": "Grand Junction",
#             "coord": {
#                 "Lat": 39.063869,
#                 "Lon": -108.550652
#             },
#             "main": {
#                 "temp": 18.68,
#                 "temp_min": 16.67,
#                 "temp_max": 20,
#                 "pressure": 1017,
#                 "humidity": 11
#             },
#             "wind": {
#                 "speed": 5.1,
#                 "deg": 240
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5780993,
#             "dt": 1553735087,
#             "name": "Salt Lake City",
#             "coord": {
#                 "Lat": 40.76078,
#                 "Lon": -111.891052
#             },
#             "main": {
#                 "temp": 17.08,
#                 "temp_min": 13.33,
#                 "temp_max": 19,
#                 "pressure": 1012,
#                 "humidity": 27
#             },
#             "wind": {
#                 "speed": 5.7,
#                 "deg": 140
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5596475,
#             "dt": 1553734940,
#             "name": "Idaho Falls",
#             "coord": {
#                 "Lat": 43.466579,
#                 "Lon": -112.034142
#             },
#             "main": {
#                 "temp": 13.08,
#                 "temp_min": 12.22,
#                 "temp_max": 14,
#                 "pressure": 1013,
#                 "humidity": 30
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 190
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5836898,
#             "dt": 1553734929,
#             "name": "Rock Springs",
#             "coord": {
#                 "Lat": 41.58746,
#                 "Lon": -109.202904
#             },
#             "main": {
#                 "temp": 13,
#                 "temp_min": 13,
#                 "temp_max": 13,
#                 "pressure": 1015,
#                 "humidity": 26
#             },
#             "wind": {
#                 "speed": 5.7,
#                 "deg": 210
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "id": 5454711,
#             "dt": 1553735086,
#             "name": "Albuquerque",
#             "coord": {
#                 "Lat": 35.084492,
#                 "Lon": -106.651138
#             },
#             "main": {
#                 "temp": 22.04,
#                 "temp_min": 17.78,
#                 "temp_max": 24.44,
#                 "pressure": 1017,
#                 "humidity": 17
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 250
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5516233,
#             "dt": 1553734914,
#             "name": "Amarillo",
#             "coord": {
#                 "Lat": 35.222,
#                 "Lon": -101.831299
#             },
#             "main": {
#                 "temp": 22.55,
#                 "temp_min": 21.67,
#                 "temp_max": 23.89,
#                 "pressure": 1015,
#                 "humidity": 53
#             },
#             "wind": {
#                 "speed": 6.2,
#                 "deg": 180
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5419384,
#             "dt": 1553735086,
#             "name": "Denver",
#             "coord": {
#                 "Lat": 39.739151,
#                 "Lon": -104.984703
#             },
#             "main": {
#                 "temp": 19.13,
#                 "temp_min": 17.22,
#                 "temp_max": 21.11,
#                 "pressure": 1014,
#                 "humidity": 22
#             },
#             "wind": {
#                 "speed": 2.21,
#                 "deg": 280.5
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5821086,
#             "dt": 1553735017,
#             "name": "Cheyenne",
#             "coord": {
#                 "Lat": 41.13998,
#                 "Lon": -104.820251
#             },
#             "main": {
#                 "temp": 14.48,
#                 "temp_min": 10,
#                 "temp_max": 17.78,
#                 "pressure": 1016,
#                 "humidity": 21
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 180
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 5768233,
#             "dt": 1553734929,
#             "name": "Rapid City",
#             "coord": {
#                 "Lat": 44.08054,
#                 "Lon": -103.23101
#             },
#             "main": {
#                 "temp": 10.25,
#                 "temp_min": 6.11,
#                 "temp_max": 14,
#                 "pressure": 1017,
#                 "humidity": 42
#             },
#             "wind": {
#                 "speed": 2.1,
#                 "deg": 50
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 3988086,
#             "dt": 1553734967,
#             "name": "Saltillo",
#             "coord": {
#                 "Lat": 25.41667,
#                 "Lon": -101
#             },
#             "main": {
#                 "temp": 18.3,
#                 "temp_min": 15.56,
#                 "temp_max": 21.11,
#                 "pressure": 1024,
#                 "humidity": 55
#             },
#             "wind": {
#                 "speed": 7.7,
#                 "deg": 20
# ...
#                 "humidity": 51
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 120
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5128581,
#             "dt": 1553734896,
#             "name": "New York",
#             "coord": {
#                 "Lat": 40.714272,
#                 "Lon": -74.005966
#             },
#             "main": {
#                 "temp": 2.84,
#                 "temp_min": 1.67,
#                 "temp_max": 4,
#                 "pressure": 1034,
#                 "humidity": 59
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 130
#             },
#             "rain": {
#                 "1h": 32.51
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 503,
#                     "main": "Rain",
#                     "description": "very heavy rain",
#                     "icon": "10n"
#                 }
#             ]
#         },
#         {
#             "id": 5128638,
#             "dt": 1553734892,
#             "name": "New York",
#             "coord": {
#                 "Lat": 43.000351,
#                 "Lon": -75.499901
#             },
#             "main": {
#                 "temp": 3.03,
#                 "temp_min": -1.11,
#                 "temp_max": 6.11,
#                 "pressure": 1028,
#                 "humidity": 32
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 120
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 4930956,
#             "dt": 1553735075,
#             "name": "Boston",
#             "coord": {
#                 "Lat": 42.358429,
#                 "Lon": -71.059769
#             },
#             "main": {
#                 "temp": 1.67,
#                 "temp_min": 0,
#                 "temp_max": 3.33,
#                 "pressure": 1032,
#                 "humidity": 37
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 160
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 4957280,
#             "dt": 1553734928,
#             "name": "Bangor",
#             "coord": {
#                 "Lat": 44.801182,
#                 "Lon": -68.777809
#             },
#             "main": {
#                 "temp": -1.11,
#                 "temp_min": -2.78,
#                 "temp_max": 0.56,
#                 "pressure": 1031,
#                 "humidity": 49
#             },
#             "wind": {
#                 "speed": 3.6,
#                 "deg": 170
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 1
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "id": 5000947,
#             "dt": 1553734928,
#             "name": "Marquette",
#             "coord": {
#                 "Lat": 46.543541,
#                 "Lon": -87.395416
#             },
#             "main": {
#                 "temp": 8.25,
#                 "temp_min": 5,
#                 "temp_max": 9.44,
#                 "pressure": 1008,
#                 "humidity": 74
#             },
#             "wind": {
#                 "speed": 7.7,
#                 "deg": 200
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 6166142,
#             "dt": 1553734936,
#             "name": "Thunder Bay",
#             "coord": {
#                 "Lat": 48.400101,
#                 "Lon": -89.316833
#             },
#             "main": {
#                 "temp": 4.63,
#                 "temp_min": 2.22,
#                 "temp_max": 7.22,
#                 "pressure": 1002,
#                 "humidity": 80
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 0
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 6141439,
#             "dt": 1553734918,
#             "name": "Sault Ste. Marie",
#             "coord": {
#                 "Lat": 46.516769,
#                 "Lon": -84.333252
#             },
#             "main": {
#                 "temp": 4.46,
#                 "temp_min": 3,
#                 "temp_max": 6,
#                 "pressure": 1013,
#                 "humidity": 64
#             },
#             "wind": {
#                 "speed": 2.1,
#                 "deg": 80
#             },
#             "rain": {
#                 "1h": 0.51
#             },
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 520,
#                     "main": "Rain",
#                     "description": "light intensity shower rain",
#                     "icon": "09n"
#                 }
#             ]
#         },
#         {
#             "id": 5964700,
#             "dt": 1553734941,
#             "name": "Greater Sudbury",
#             "coord": {
#                 "Lat": 46.490002,
#                 "Lon": -80.990013
#             },
#             "main": {
#                 "temp": 2.3,
#                 "temp_min": 2,
#                 "temp_max": 2.78,
#                 "pressure": 1017,
#                 "humidity": 55
#             },
#             "wind": {
#                 "speed": 8.7,
#                 "deg": 190
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 6089426,
#             "dt": 1553734894,
#             "name": "North Bay",
#             "coord": {
#                 "Lat": 46.316799,
#                 "Lon": -79.466331
#             },
#             "main": {
#                 "temp": 2.22,
#                 "temp_min": 0.56,
#                 "temp_max": 3.89,
#                 "pressure": 1019,
#                 "humidity": 59
#             },
#             "wind": {
#                 "speed": 7.2,
#                 "deg": 210
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 6166739,
#             "dt": 1553734917,
#             "name": "Timmins",
#             "coord": {
#                 "Lat": 48.466862,
#                 "Lon": -81.333122
#             },
#             "main": {
#                 "temp": 1,
#                 "temp_min": 1,
#                 "temp_max": 1,
#                 "pressure": 1010,
#                 "humidity": 86
#             },
#             "wind": {
#                 "speed": 5.1,
#                 "deg": 190
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 600,
#                     "main": "Snow",
#                     "description": "light snow",
#                     "icon": "13n"
#                 }
#             ]
#         },
#         {
#             "id": 6173017,
#             "dt": 1553734967,
#             "name": "Val-dOr",
#             "coord": {
#                 "Lat": 48.100182,
#                 "Lon": -77.782799
#             },
#             "main": {
#                 "temp": 4,
#                 "temp_min": 4,
#                 "temp_max": 4,
#                 "pressure": 1017,
#                 "humidity": 38
#             },
#             "wind": {
#                 "speed": 6.7,
#                 "deg": 200
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 90
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 6094817,
#             "dt": 1553734950,
#             "name": "Ottawa",
#             "coord": {
#                 "Lat": 45.411171,
#                 "Lon": -75.69812
#             },
#             "main": {
#                 "temp": 1.42,
#                 "temp_min": 0,
#                 "temp_max": 3,
#                 "pressure": 1026,
#                 "humidity": 37
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 200
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 40
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ]
#         },
#         {
#             "id": 6077243,
#             "dt": 1553734941,
#             "name": "Montreal",
#             "coord": {
#                 "Lat": 45.508839,
#                 "Lon": -73.587807
#             },
#             "main": {
#                 "temp": 1.01,
#                 "temp_min": -2.22,
#                 "temp_max": 4,
#                 "pressure": 1027,
#                 "humidity": 38
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 160
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 6325494,
#             "dt": 1553734966,
#             "name": "Quebec",
#             "coord": {
#                 "Lat": 46.812279,
#                 "Lon": -71.214539
#             },
#             "main": {
#                 "temp": -1.32,
#                 "temp_min": -4,
#                 "temp_max": 0,
#                 "pressure": 1027,
#                 "humidity": 68
#             },
#             "wind": {
#                 "speed": 3.1,
#                 "deg": 250
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "id": 6137270,
#             "dt": 1553734936,
#             "name": "Saguenay",
#             "coord": {
#                 "Lat": 48.416752,
#                 "Lon": -71.065727
#             },
#             "main": {
#                 "temp": 3.06,
#                 "temp_min": 2.22,
#                 "temp_max": 4,
#                 "pressure": 1022,
#                 "humidity": 44
#             },
#             "wind": {
#                 "speed": 4.6,
#                 "deg": 200
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5884083,
#             "dt": 1553734943,
#             "name": "Alma",
#             "coord": {
#                 "Lat": 48.550091,
#                 "Lon": -71.649101
#             },
#             "main": {
#                 "temp": 3.49,
#                 "temp_min": 2.22,
#                 "temp_max": 4,
#                 "pressure": 1020,
#                 "humidity": 32
#             },
#             "wind": {
#                 "speed": 4.1,
#                 "deg": 200
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 6354895,
#             "dt": 1553734936,
#             "name": "Rimouski",
#             "coord": {
#                 "Lat": 48.448792,
#                 "Lon": -68.523956
#             },
#             "main": {
#                 "temp": -0.59,
#                 "temp_min": -2.78,
#                 "temp_max": 2,
#                 "pressure": 1023,
#                 "humidity": 34
#             },
#             "wind": {
#                 "speed": 3.6,
#                 "deg": 200
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 75
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ]
#         },
#         {
#             "id": 5889745,
#             "dt": 1553734967,
#             "name": "Baie-Comeau",
#             "coord": {
#                 "Lat": 49.216789,
#                 "Lon": -68.148941
#             },
#             "main": {
#                 "temp": -0.08,
#                 "temp_min": -2.78,
#                 "temp_max": 2,
#                 "pressure": 1022,
#                 "humidity": 55
#             },
#             "wind": {
#                 "speed": 10.8,
#                 "deg": 240
#             },
#             "rain": null,
#             "snow": null,
#             "clouds": {
#                 "today": 20
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         }
#     ]
# }
